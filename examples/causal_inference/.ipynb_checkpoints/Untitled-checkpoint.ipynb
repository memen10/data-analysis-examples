# %% [markdown]
# # Causal Impact (tfCausalImpact)  sample

# %% [markdown]
# ## Ref.
# https://github.com/google/CausalImpact
# https://github.com/WillianFuks/tfcausalimpact

# %% [markdown]
# ## Requirements:
# ```
# python{3.6, 3.7, 3.8}
# matplotlib
# jinja2
# tensorflow>=2.3.0
# tensorflow_probability>=0.11.0
# ```

# %%
pip install tfcausalimpact
# Out:
# Collecting tfcausalimpact
#   Downloading tfcausalimpact-0.0.9.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jinja2 in /Users/diyosko7/Workspace/data-analysis-examples/venv/lib/python3.8/site-packages (from tfcausalimpact) (3.0.3)
# Collecting pandas
#   Downloading pandas-1.4.1-cp38-cp38-macosx_10_9_x86_64.whl (11.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 14.5 MB/s eta 0:00:00m eta 0:00:010:0101
# Collecting tensorflow
#   Downloading tensorflow-2.8.0-cp38-cp38-macosx_10_14_x86_64.whl (217.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.4/217.4 MB 8.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting tensorflow-probability>=0.14.0
#   Downloading tensorflow_probability-0.16.0-py2.py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 14.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp38-cp38-macosx_10_9_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 13.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting dm-tree
#   Downloading dm_tree-0.1.6-cp38-cp38-macosx_10_14_x86_64.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.4/95.4 KB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.10.0 in /Users/diyosko7/Workspace/data-analysis-examples/venv/lib/python3.8/site-packages (from tensorflow-probability>=0.14.0->tfcausalimpact) (1.16.0)
# Collecting cloudpickle>=1.3
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting gast>=0.3.2
#   Downloading gast-0.5.3-py3-none-any.whl (19 kB)
# Collecting numpy>=1.13.3
#   Downloading numpy-1.22.2-cp38-cp38-macosx_10_14_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 12.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting absl-py
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 KB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /Users/diyosko7/Workspace/data-analysis-examples/venv/lib/python3.8/site-packages (from tensorflow-probability>=0.14.0->tfcausalimpact) (5.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/diyosko7/Workspace/data-analysis-examples/venv/lib/python3.8/site-packages (from jinja2->tfcausalimpact) (2.1.0)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.3.2-cp38-cp38-macosx_10_9_x86_64.whl (61 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.0.1-cp38-cp38-macosx_10_10_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 13.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/diyosko7/Workspace/data-analysis-examples/venv/lib/python3.8/site-packages (from matplotlib->tfcausalimpact) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /Users/diyosko7/Workspace/data-analysis-examples/venv/lib/python3.8/site-packages (from matplotlib->tfcausalimpact) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/diyosko7/Workspace/data-analysis-examples/venv/lib/python3.8/site-packages (from matplotlib->tfcausalimpact) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.29.1-py3-none-any.whl (895 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 895.5/895.5 KB 12.2 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.44.0-cp38-cp38-macosx_10_10_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 10.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.19.4-cp38-cp38-macosx_10_9_x86_64.whl (961 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.7/961.7 KB 13.7 MB/s eta 0:00:0031m22.3 MB/s eta 0:00:01
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.13.3-cp38-cp38-macosx_10_9_x86_64.whl (33 kB)
# Collecting typing-extensions>=3.6.6
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Collecting flatbuffers>=1.12
#   Downloading flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.24.0-cp38-cp38-macosx_10_14_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 13.8 MB/s eta 0:00:00m eta 0:00:010:01
# Requirement already satisfied: setuptools in /Users/diyosko7/Workspace/data-analysis-examples/venv/lib/python3.8/site-packages (from tensorflow->tfcausalimpact) (60.9.3)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 11.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting keras<2.9,>=2.8.0rc0
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 14.3 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting h5py>=2.9.0
#   Downloading h5py-3.6.0-cp38-cp38-macosx_10_9_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 12.6 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 KB 7.0 MB/s eta 0:00:00m eta 0:00:01
# Collecting libclang>=9.0.1
#   Downloading libclang-13.0.0-py2.py3-none-macosx_10_9_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 11.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.6.0-py2.py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 KB 9.5 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 KB 4.9 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 KB 9.5 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.2/289.2 KB 8.4 MB/s eta 0:00:00
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 KB 3.9 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.11.2-py3-none-any.whl (17 kB)
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.8-py2.py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 KB 7.6 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/diyosko7/Workspace/data-analysis-examples/venv/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->tfcausalimpact) (3.7.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 KB 9.1 MB/s eta 0:00:00
# Using legacy 'setup.py install' for tfcausalimpact, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for termcolor, since package 'wheel' is not installed.
# Installing collected packages: tf-estimator-nightly, termcolor, tensorboard-plugin-wit, pytz, pyasn1, libclang, keras, flatbuffers, certifi, wrapt, wheel, werkzeug, urllib3, typing-extensions, tensorflow-io-gcs-filesystem, tensorboard-data-server, rsa, pyasn1-modules, protobuf, pillow, oauthlib, numpy, kiwisolver, importlib-metadata, idna, grpcio, google-pasta, gast, fonttools, dm-tree, cycler, cloudpickle, charset-normalizer, cachetools, absl-py, tensorflow-probability, requests, pandas, opt-einsum, matplotlib, markdown, keras-preprocessing, h5py, google-auth, astunparse, requests-oauthlib, google-auth-oauthlib, tensorboard, tensorflow, tfcausalimpact
#   Running setup.py install for termcolor ... done
#   Running setup.py install for tfcausalimpact ... done
# Successfully installed absl-py-1.0.0 astunparse-1.6.3 cachetools-5.0.0 certifi-2021.10.8 charset-normalizer-2.0.12 cloudpickle-2.0.0 cycler-0.11.0 dm-tree-0.1.6 flatbuffers-2.0 fonttools-4.29.1 gast-0.5.3 google-auth-2.6.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.44.0 h5py-3.6.0 idna-3.3 importlib-metadata-4.11.2 keras-2.8.0 keras-preprocessing-1.1.2 kiwisolver-1.3.2 libclang-13.0.0 markdown-3.3.6 matplotlib-3.5.1 numpy-1.22.2 oauthlib-3.2.0 opt-einsum-3.3.0 pandas-1.4.1 pillow-9.0.1 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 pytz-2021.3 requests-2.27.1 requests-oauthlib-1.3.1 rsa-4.8 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.8.0 tensorflow-io-gcs-filesystem-0.24.0 tensorflow-probability-0.16.0 termcolor-1.1.0 tf-estimator-nightly-2.8.0.dev2021122109 tfcausalimpact-0.0.9 typing-extensions-4.1.1 urllib3-1.26.8 werkzeug-2.0.3 wheel-0.37.1 wrapt-1.13.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Examples 1
# Here's a simple example (which can also be found in the original Google's R implementation) running in Python:
# 施策効果を、施策リリース前後の数値をもとに推定・可視化するサンプル

# %%
import pandas as pd
from causalimpact import CausalImpact

data = pd.read_csv('https://raw.githubusercontent.com/WillianFuks/tfcausalimpact/master/tests/fixtures/arma_data.csv')[['y', 'X']]
data = data.rename(columns={"y": "cvs"})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cvs     100 non-null    float64
#  1   X       100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %%
data.describe()
# Out:
#               cvs           X
# count  100.000000  100.000000
# mean   119.998008  100.027993
# std      3.031643    2.414932
# min    112.952398   94.436656
# 25%    118.072594   98.340170
# 50%    119.932836  100.103918
# 75%    122.261444  101.766060
# max    126.838436  105.149309

# %%
#  treatment effect
data['cvs'][70:] += 5

# treatment release period 
pre_period = [0, 69]
post_period = [70, 99]

# %%
ci = CausalImpact(data, pre_period, post_period)
print(ci.summary())
print(ci.summary(output='report'))
ci.plot()
# Out:
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:@custom_gradient grad_fn has 'variables' in signature, but no ResourceVariables were used on the forward pass.
# WARNING:tensorflow:5 out of the last 5 calls to <bound method LinearGaussianStateSpaceModel.forward_filter of <tfp.distributions.AdditiveStateSpaceModel 'AdditiveStateSpaceModel' batch_shape=[100] event_shape=[70, 1] dtype=float32>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <bound method LinearGaussianStateSpaceModel.forward_filter of <tfp.distributions.AdditiveStateSpaceModel 'AdditiveStateSpaceModel' batch_shape=[100] event_shape=[70, 1] dtype=float32>> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Posterior Inference {Causal Impact}
#                           Average            Cumulative
# Actual                    125.23             3756.86
# Prediction (s.d.)         120.34 (0.3)       3610.33 (8.98)
# 95% CI                    [119.74, 120.91]   [3592.24, 3627.42]
#
# Absolute effect (s.d.)    4.88 (0.3)         146.53 (8.98)
# 95% CI                    [4.31, 5.49]       [129.44, 164.63]
#
# Relative effect (s.d.)    4.06% (0.25%)      4.06% (0.25%)
# 95% CI                    [3.59%, 4.56%]     [3.59%, 4.56%]
#
# Posterior tail-area probability p: 0.0
# Posterior prob. of a causal effect: 100.0%
#
# For more details run the command: print(impact.summary('report'))
# Analysis report {CausalImpact}
#
#
# During the post-intervention period, the response variable had
# an average value of approx. 125.23. By contrast, in the absence of an
# intervention, we would have expected an average response of 120.34.
# The 95% interval of this counterfactual prediction is [119.74, 120.91].
# Subtracting this prediction from the observed response yields
# an estimate of the causal effect the intervention had on the
# response variable. This effect is 4.88 with a 95% interval of
# [4.31, 5.49]. For a discussion of the significance of this effect,
# see below.
#
#
# Summing up the individual data points during the post-intervention
# period (which can only sometimes be meaningfully interpreted), the
# response variable had an overall value of 3756.86.
# By contrast, had the intervention not taken place, we would have expected
# a sum of 3610.33. The 95% interval of this prediction is [3592.24, 3627.42].
#
#
# The above results are given in terms of absolute numbers. In relative
# terms, the response variable showed an increase of +4.06%. The 95%
# interval of this percentage is [3.59%, 4.56%].
#
#
# This means that the positive effect observed during the intervention
# period is statistically significant and unlikely to be due to random
# fluctuations. It should be noted, however, that the question of whether
# this increase also bears substantive significance can only be answered
# by comparing the absolute effect (4.88) to the original goal
# of the underlying intervention.
#
#
# The probability of obtaining this effect by chance is very small
# (Bayesian one-sided tail-area probability p = 0.0).
# This means the causal effect can be considered statistically
# significant.
